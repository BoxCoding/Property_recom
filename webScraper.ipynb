# %%
import os
from bs4 import BeautifulSoup
from selenium import webdriver
import sys
import json
import pandas as pd
import numpy as np

# %%
path="D:/scrapping/magicbricks/"

# %%
def get_driver():
    
    chromedriver = "D:/download/chromedriver" # path to the chromedriver executable
    chromedriver = os.path.expanduser(chromedriver)
    print('chromedriver path: {}'.format(chromedriver))
    sys.path.append(chromedriver)
    driver = webdriver.Chrome(chromedriver)
    return driver

# %%
def get_house_links():
    driver=get_driver()
    house_links=[]
    cities=['Noida']
    for city in cities:
        for i in range(1,120):
            driver.get("https://www.magicbricks.com/property-for-sale/residential-real-estate?proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment,Villa&page="+str(i)+"&cityName="+str(city))
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            get_data(soup)

# %%
def get_dictvalues(dictlist,column):
    if column in dictlist.keys():
        return dictlist[column]
    else:
        return ''

# %%
def get_data(soup):
    h=[]
    prop=soup.find_all('div',class_='m-srp-card SRCard')
    """prop1=soup.find_all('div',class_='propOverView ')
    locality=soup.find_all('div', class_='m-srp-card__society')"""
    #print(prop1)
    for i in prop:
        item_dict={}
        name=""
        id_=""
        description=""
        url=""
        price=""
        priceInWord=""
        cityName=""
        addressLocality=""
        longitude=""
        latitude=""
        numberOfRooms=""
        bathroom=""
        bedroom=""
        floorSize=""
        floorno=""
        furnshingstatus=""
        agentName=""
        agentCompanyName=""
        agentMaskedmobilenumber=""
        society=""
        builder=""
        property_type=""
        locality=""
        createdDate=""
        postedBy=""
        meta=i.find_all('meta')
        for m in meta:
            if m['itemprop']=='name':
                name=m['content']
            if m['itemprop']=='description':
                description=m['content']
            """if m['itemprop']=='url':
                url=str('https://www.magicbricks.com'+m['content'])"""
            if m['itemprop']=='addressLocality':
                addressLocality=m['content']
            if m['itemprop']=='longitude':
                longitude=m['content']
            if m['itemprop']=='latitude':
                latitude=m['content']
            if m['itemprop']=='numberOfRooms':
                numberOfRooms=m['content']
            if m['itemprop']=='floorSize':
                floorSize=m['content']
        s=i.find('span',class_='hidden')
        bathroom=s['data-bathroom']
        bedroom=s['data-bedroom']
        floorno=s['data-floorno']
        society=s['data-projectname']
        builder=s['data-devname']
        property_type=s['data-propertyval']
        postedBy=s['data-usertype']
        createdDate=s['data-createdate']
        #print(society)
        furnshingstatus=s['data-furnshingstatus']
        price=s['data-price']
        id_=s['id']
        ag=soup.find('span',id=id_)
        priceInWord=ag['data-priced']
        cityName=ag['data-cityname']
        agentName=ag['data-soname']
        agentCompanyName=ag['data-companyname']
        agentMaskedmobilenumber=ag['data-maskedmobilenumber']
        url=ag['data-detailurl']
        locality=ag['data-objlmtdname']
        #print(locality)
        var = {
                "name":name,
                "id":id_,
                "createdDate":createdDate,
                "description":description,
                "Society":society,
                "url":url,
                "price":price,
                "priceInWord":priceInWord,
                "cityName":cityName,
                "addressLocality":addressLocality,
                "longitude":longitude,
                "latitude":latitude,
                "numberOfRooms":numberOfRooms,
                "bathroom":bathroom,
                "bedroom":bedroom,
                "floorSize":floorSize,
                "floorno":floorno,
                "furnshingstatus":furnshingstatus,
                "agentName":agentName,
                "agentCompanyName":agentCompanyName,
                "agentMaskedmobilenumber":agentMaskedmobilenumber,
                "projectName":society,
                "builderName":builder,
                "propertyType":property_type,
                "locality":locality,
                "postedBy":postedBy
                
            }
        #print(var)
        h.append(var)
    with open(f"{path}data_noida_jan.json",'r+') as f:
        feeds = json.load(f)
        for i in h:
            feeds['property'].append(i)
        f.seek(0)
        json.dump(feeds, f)

# %%
v={
    "property":[]
}
with open(f"{path}data_noida_jan.json", mode='w', encoding='utf-8') as f:
    json.dump(v,f)

# %%
get_house_links()
# Out:
# chromedriver path: D:/download/chromedriver

# %%
#df_json=pd.read_json(f'{path}data_NCR.json')

# %%
from pandas.io.json import json_normalize

# %%
with open(f'{path}data_noida_jan.json') as f: 
    d = json.load(f) 
  

    df_json = json_normalize(d['property']) 
df_json.head(3)
# Out:
#                      Society                     addressLocality  \
# 0  ATS Picturesque Reprieves       Sector 152, Noida Express Way
# 1                 Wave Amore  Sector 32, Noida City centre Metro
# 2                 Burj Noida                           Sector 75
#
#                   agentCompanyName agentMaskedmobilenumber       agentName  \
# 0               ATS Infrastructure         +91-89XXXXXXX51   Vivek  Pandey
# 1  Wave Mega City Centre Pvt. Ltd.         +91-99XXXXXXX49  Wave Infratech
# 2      Investec Property Solutions         +91-82XXXXXXX35           Sumit
#
#   bathroom bedroom              builderName cityName createdDate  ...  \
# 0        3       3  ATS Infrastructure Ltd.    Noida    20200121  ...
# 1        2       2           Wave Infratech    Noida    20200108  ...
# 2        5       4          DASNAC HOLDINGS    Noida    20200127  ...
#
#                              locality  longitude  \
# 0       Sector 152, Noida Express Way  28.441405
# 1  Sector 32, Noida City centre Metro   28.57853
# 2                           Sector 75  28.575524
#
#                                                 name numberOfRooms postedBy  \
# 0  3 BHK Apartment for Sale in Sector 152, Noida ...             3  Builder
# 1  2 BHK Apartment for Sale in Sector 32, Noida C...             2  Builder
# 2              4 BHK Apartment for Sale in Sector 75             4    Agent
#
#       price priceInWord                projectName propertyType  \
# 0   8800000      88 Lac  ATS Picturesque Reprieves    Apartment
# 1  21300000     2.13 Cr                 Wave Amore    Apartment
# 2  30000000        3 Cr                 Burj Noida    Apartment
#
#                                                  url
# 0  https://www.magicbricks.com/propertyDetails/3-...
# 1  https://www.magicbricks.com/propertyDetails/2-...
# 2  https://www.magicbricks.com/propertyDetails/4-...
#
# [3 rows x 26 columns]

# %%
df_json.head()
# Out:
#                      Society                     addressLocality  \
# 0  ATS Picturesque Reprieves       Sector 152, Noida Express Way
# 1                 Wave Amore  Sector 32, Noida City centre Metro
# 2                 Burj Noida                           Sector 75
# 3        Panchsheel Greens 2                     Noida Extension
# 4                 The Romano                          Sector 118
#
#                   agentCompanyName agentMaskedmobilenumber       agentName  \
# 0               ATS Infrastructure         +91-89XXXXXXX51   Vivek  Pandey
# 1  Wave Mega City Centre Pvt. Ltd.         +91-99XXXXXXX49  Wave Infratech
# 2      Investec Property Solutions         +91-82XXXXXXX35           Sumit
# 3   Panchsheel Buildtech Pvt. Ltd.         +91-98XXXXXXX82       Komal NFE
# 4                Supertech Limited         +91-92XXXXXXX45   Raman  Shukla
#
#   bathroom bedroom                    builderName cityName createdDate  ...  \
# 0        3       3        ATS Infrastructure Ltd.    Noida    20200121  ...
# 1        2       2                 Wave Infratech    Noida    20200108  ...
# 2        5       4                DASNAC HOLDINGS    Noida    20200127  ...
# 3        2       2  Panchsheel Builtech Pvt. Ltd.    Noida    20200122  ...
# 4        4       3                 Supertech Ltd.    Noida    20191025  ...
#
#                              locality        longitude  \
# 0       Sector 152, Noida Express Way        28.441405
# 1  Sector 32, Noida City centre Metro         28.57853
# 2                           Sector 75        28.575524
# 3                     Noida Extension          28.5329
# 4                          Sector 118  28.584165020633
#
#                                                 name numberOfRooms postedBy  \
# 0  3 BHK Apartment for Sale in Sector 152, Noida ...             3  Builder
# 1  2 BHK Apartment for Sale in Sector 32, Noida C...             2  Builder
# 2              4 BHK Apartment for Sale in Sector 75             4    Agent
# 3        2 BHK Apartment for Sale in Noida Extension             2  Builder
# 4             3 BHK Apartment for Sale in Sector 118             3  Builder
#
#       price priceInWord                projectName propertyType  \
# 0   8800000      88 Lac  ATS Picturesque Reprieves    Apartment
# 1  21300000     2.13 Cr                 Wave Amore    Apartment
# 2  30000000        3 Cr                 Burj Noida    Apartment
# 3   3480000    34.8 Lac        Panchsheel Greens 2    Apartment
# 4   7400000      74 Lac                 The Romano    Apartment
#
#                                                  url
# 0  https://www.magicbricks.com/propertyDetails/3-...
# 1  https://www.magicbricks.com/propertyDetails/2-...
# 2  https://www.magicbricks.com/propertyDetails/4-...
# 3  https://www.magicbricks.com/propertyDetails/2-...
# 4  https://www.magicbricks.com/propertyDetails/3-...
#
# [5 rows x 26 columns]

# %%
df_json.columns
# Out:
# Index(['Society', 'addressLocality', 'agentCompanyName',
#        'agentMaskedmobilenumber', 'agentName', 'bathroom', 'bedroom',
#        'builderName', 'cityName', 'createdDate', 'description', 'floorSize',
#        'floorno', 'furnshingstatus', 'id', 'latitude', 'locality', 'longitude',
#        'name', 'numberOfRooms', 'postedBy', 'price', 'priceInWord',
#        'projectName', 'propertyType', 'url'],
#       dtype='object')

# %%
df_json.shape
# Out:
# (3077, 26)

# %%
df_json.drop_duplicates(inplace=True)

# %%
df_json.head()
# Out:
#                      Society                     addressLocality  \
# 0  ATS Picturesque Reprieves       Sector 152, Noida Express Way
# 1                 Wave Amore  Sector 32, Noida City centre Metro
# 2                 Burj Noida                           Sector 75
# 3        Panchsheel Greens 2                     Noida Extension
# 4                 The Romano                          Sector 118
#
#                   agentCompanyName agentMaskedmobilenumber       agentName  \
# 0               ATS Infrastructure         +91-89XXXXXXX51   Vivek  Pandey
# 1  Wave Mega City Centre Pvt. Ltd.         +91-99XXXXXXX49  Wave Infratech
# 2      Investec Property Solutions         +91-82XXXXXXX35           Sumit
# 3   Panchsheel Buildtech Pvt. Ltd.         +91-98XXXXXXX82       Komal NFE
# 4                Supertech Limited         +91-92XXXXXXX45   Raman  Shukla
#
#   bathroom bedroom                    builderName cityName createdDate  ...  \
# 0        3       3        ATS Infrastructure Ltd.    Noida    20200121  ...
# 1        2       2                 Wave Infratech    Noida    20200108  ...
# 2        5       4                DASNAC HOLDINGS    Noida    20200127  ...
# 3        2       2  Panchsheel Builtech Pvt. Ltd.    Noida    20200122  ...
# 4        4       3                 Supertech Ltd.    Noida    20191025  ...
#
#                              locality        longitude  \
# 0       Sector 152, Noida Express Way        28.441405
# 1  Sector 32, Noida City centre Metro         28.57853
# 2                           Sector 75        28.575524
# 3                     Noida Extension          28.5329
# 4                          Sector 118  28.584165020633
#
#                                                 name numberOfRooms postedBy  \
# 0  3 BHK Apartment for Sale in Sector 152, Noida ...             3  Builder
# 1  2 BHK Apartment for Sale in Sector 32, Noida C...             2  Builder
# 2              4 BHK Apartment for Sale in Sector 75             4    Agent
# 3        2 BHK Apartment for Sale in Noida Extension             2  Builder
# 4             3 BHK Apartment for Sale in Sector 118             3  Builder
#
#       price priceInWord                projectName propertyType  \
# 0   8800000      88 Lac  ATS Picturesque Reprieves    Apartment
# 1  21300000     2.13 Cr                 Wave Amore    Apartment
# 2  30000000        3 Cr                 Burj Noida    Apartment
# 3   3480000    34.8 Lac        Panchsheel Greens 2    Apartment
# 4   7400000      74 Lac                 The Romano    Apartment
#
#                                                  url
# 0  https://www.magicbricks.com/propertyDetails/3-...
# 1  https://www.magicbricks.com/propertyDetails/2-...
# 2  https://www.magicbricks.com/propertyDetails/4-...
# 3  https://www.magicbricks.com/propertyDetails/2-...
# 4  https://www.magicbricks.com/propertyDetails/3-...
#
# [5 rows x 26 columns]

# %%
df_json.shape
# Out:
# (2602, 26)

# %%
df_json.head().T
# Out:
#                                                                          0  \
# Society                                          ATS Picturesque Reprieves
# addressLocality                              Sector 152, Noida Express Way
# agentCompanyName                                        ATS Infrastructure
# agentMaskedmobilenumber                                    +91-89XXXXXXX51
# agentName                                                    Vivek  Pandey
# bathroom                                                                 3
# bedroom                                                                  3
# builderName                                        ATS Infrastructure Ltd.
# cityName                                                             Noida
# createdDate                                                       20200121
# description              3 Bath,Semi-Furnished,7 floor As the name impl...
# floorSize                                                        1850 FTK
# floorno                                                                  7
# furnshingstatus                                             Semi-Furnished
# id                                                   domcache_srp_44726207
# latitude                                                         77.476994
# locality                                     Sector 152, Noida Express Way
# longitude                                                        28.441405
# name                     3 BHK Apartment for Sale in Sector 152, Noida ...
# numberOfRooms                                                            3
# postedBy                                                           Builder
# price                                                              8800000
# priceInWord                                                         88 Lac
# projectName                                      ATS Picturesque Reprieves
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/3-...
#
#                                                                          1  \
# Society                                                         Wave Amore
# addressLocality                         Sector 32, Noida City centre Metro
# agentCompanyName                           Wave Mega City Centre Pvt. Ltd.
# agentMaskedmobilenumber                                    +91-99XXXXXXX49
# agentName                                                   Wave Infratech
# bathroom                                                                 2
# bedroom                                                                  2
# builderName                                                 Wave Infratech
# cityName                                                             Noida
# createdDate                                                       20200108
# description              2 Bath,Furnished,15 floor AMORE 2, 3 & 4 BEDRO...
# floorSize                                                        2135 FTK
# floorno                                                                 15
# furnshingstatus                                                  Furnished
# id                                                   domcache_srp_46965983
# latitude                                                         77.347635
# locality                                Sector 32, Noida City centre Metro
# longitude                                                         28.57853
# name                     2 BHK Apartment for Sale in Sector 32, Noida C...
# numberOfRooms                                                            2
# postedBy                                                           Builder
# price                                                             21300000
# priceInWord                                                        2.13 Cr
# projectName                                                     Wave Amore
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/2-...
#
#                                                                          2  \
# Society                                                         Burj Noida
# addressLocality                                                  Sector 75
# agentCompanyName                               Investec Property Solutions
# agentMaskedmobilenumber                                    +91-82XXXXXXX35
# agentName                                                            Sumit
# bathroom                                                                 5
# bedroom                                                                  4
# builderName                                                DASNAC HOLDINGS
# cityName                                                             Noida
# createdDate                                                       20200127
# description              5 Bath,Unfurnished 3 & 4 BHK Super-sized luxur...
# floorSize                                                        3300 FTK
# floorno
# furnshingstatus                                                Unfurnished
# id                                                   domcache_srp_46349109
# latitude                                                         77.381929
# locality                                                         Sector 75
# longitude                                                        28.575524
# name                                 4 BHK Apartment for Sale in Sector 75
# numberOfRooms                                                            4
# postedBy                                                             Agent
# price                                                             30000000
# priceInWord                                                           3 Cr
# projectName                                                     Burj Noida
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/4-...
#
#                                                                          3  \
# Society                                                Panchsheel Greens 2
# addressLocality                                            Noida Extension
# agentCompanyName                            Panchsheel Buildtech Pvt. Ltd.
# agentMaskedmobilenumber                                    +91-98XXXXXXX82
# agentName                                                        Komal NFE
# bathroom                                                                 2
# bedroom                                                                  2
# builderName                                  Panchsheel Builtech Pvt. Ltd.
# cityName                                                             Noida
# createdDate                                                       20200122
# description              2 Bath,Furnished,18 floor Spread over in 26 ac...
# floorSize                                                        1105 FTK
# floorno                                                                 18
# furnshingstatus                                                  Furnished
# id                                                   domcache_srp_47489765
# latitude                                                         77.407621
# locality                                                   Noida Extension
# longitude                                                          28.5329
# name                           2 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            2
# postedBy                                                           Builder
# price                                                              3480000
# priceInWord                                                       34.8 Lac
# projectName                                            Panchsheel Greens 2
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/2-...
#
#                                                                          4
# Society                                                         The Romano
# addressLocality                                                 Sector 118
# agentCompanyName                                         Supertech Limited
# agentMaskedmobilenumber                                    +91-92XXXXXXX45
# agentName                                                    Raman  Shukla
# bathroom                                                                 4
# bedroom                                                                  3
# builderName                                                 Supertech Ltd.
# cityName                                                             Noida
# createdDate                                                       20191025
# description              4 Bath,Unfurnished The apartment is in Sector-...
# floorSize                                                        1900 FTK
# floorno
# furnshingstatus                                                Unfurnished
# id                                                   domcache_srp_13331785
# latitude                                                  77.4064917144491
# locality                                                        Sector 118
# longitude                                                  28.584165020633
# name                                3 BHK Apartment for Sale in Sector 118
# numberOfRooms                                                            3
# postedBy                                                           Builder
# price                                                              7400000
# priceInWord                                                         74 Lac
# projectName                                                     The Romano
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/3-...

# %%
df_json.to_csv(f'{path}data_data_noida_jan_jan.csv')

# %%
df_json.locality.unique()
# Out:
# array(['Sector 152, Noida Express Way',
#        'Sector 32, Noida City centre Metro', 'Sector 75',
#        'Noida Extension', 'Sector 118', 'Sector 121',
#        'Sector 137, Noida Express Way', 'Sector 150, Pusta Road',
#        'Sector 94, Noida Express Way', 'Sector 50', 'Sector 52',
#        'Greater Noida West', 'Noida Extension Block C',
#        'Sector 128, Noida Express Way', 'Sector 74',
#        'Sector 143, Noida Express Way', 'Sector 104, Noida Express Way',
#        'Sector 77', 'Noida Extension Block A', 'Sector 76',
#        'Sector 16B, Noida sector 16 Metro',
#        'Sector 168, Noida Express Way', 'Sector 61, Ashok Marg',
#        'Sector 1', 'Sector 62, NH  24', 'Sector 73, Noida Express Way',
#        '', 'Sector 78', 'Sector 45, Noida Express Way',
#        'Sector 133, Noida Express Way', 'Sector 143 B, Noida Express Way',
#        'Sector 44, Dadri Road', 'Sector 120', 'Sector 50 Block A',
#        'Sector 119, Pusta Road', 'Sector 68 Block A', 'Jalvayu Vihar',
#        'Sector 26 Block C, Noida sector 18 Metro',
#        'Sector 135, Noida Express Way', 'Sector 46',
#        'Sector 79, Dadri Road', 'Sector 29',
#        'Taj Expressway, Greater Noida West',
#        'Sector 70, Noida Express Way', 'Chhalera, Sector 44, Dadri Road',
#        'Sector 106, Dadri Road', 'Sector 82, Dadri Road', 'Sector 34',
#        'Sector 129, Noida Express Way', 'Sector 93A, Noida Express Way',
#        'Sector 100 Block B', 'Sector 93, Noida Express Way',
#        'Sector 151, Noida Express Way', 'Sector 107, Dadri Road',
#        'Sector 110, Dadri Road', 'Sector 131, Noida Express Way',
#        'Sector 134, Noida Express Way', 'Noida Extension Block B',
#        'Sector 49, Dadri Road', 'Rail Vihar Sector 33, Sector 33',
#        'Sector 35, Noida City centre Metro', 'Sector 100 Block A',
#        'Kendriya Vihar, Sector 51', 'Sector 50 Block F', 'Sector 51',
#        'Sector 117', 'Sector 16', 'Sector 100',
#        'Sector 42 Block E, Dadri Road', 'Sector 4, Noida sector 16 Metro',
#        'Sector 25', 'Sector 17', 'Sector 11', 'Sector 47, Dadri Road',
#        'Sector 2, Noida sector 15 Metro', 'Sector 72 Block C',
#        'Sector 92 Block A, Noida Express Way', 'Sector 21', 'Sector 71',
#        'Sector 37, Golf course Metro', 'Sector 15A, Noida Express Way',
#        'Sector 21 Block P', 'Sector 48, Dadri Road', 'Dadri Road',
#        'Sector 39, Noida City centre Metro', 'Sector 62 Block B, NH  24',
#        'Sector 41, Dadri Road', 'Noida City centre Metro',
#        'Sector 126, Noida Express Way',
#        'Sultanpur, Sector 128, Noida Express Way', 'Gadarpur, Sector 99',
#        'Hosiery Complex, Noida Extension, Dadri Road', 'Sector 61Block E',
#        'Sector-27, Noida sector 18 Metro',
#        'Sector 26 Block A, Noida sector 18 Metro', 'Surajpur',
#        'Sector 144, Noida Express Way', 'Sector 19 Pocket A',
#        'Noida Extension Block D', 'Sector 40, Dadri Road',
#        'Sector 108, Noida Express Way', 'Sector 93B, Noida Express Way',
#        'Sector 28, Noida Sector 18 Metro', 'Gijhore, Sector 53',
#        'Sector 2 Block D, Noida sector 15 Metro',
#        'Sector 49 Block B, Dadri Road', 'Noida Express Way',
#        'Sector 19 Pocket C', 'Sector 99', 'Sector 62A',
#        'Sarafabad, Noida Express Way', 'Sector 33', 'Noida Extention',
#        'Sector 27 Pocket F', 'Arun Vihar, Sector 37, Golf course Metro',
#        'Sector 65', 'Hindon Vihar, Sector 49, Dadri Road',
#        'Sector 30, Golf Course Metro', 'Sector 105, Noida Express Way',
#        'Sector 94A', 'Sector 41 Block E, Dadri Road', 'Sector 46 Block A',
#        'Sector 12', 'Sector 143A, Noida Express Way', 'Sector 90',
#        'Sector 26, Noida sector 18 Metro',
#        'Sector 108 Block A, Noida Express Way', 'Sector 22 Block H',
#        'Ram Vihar, Sector 30', 'Sector 42, Dadri Road',
#        'Asgerpur, Sector 131, Noida Express Way', 'Sector 52 Block C',
#        'Sector 84', 'Sector 10', 'Sector 53, Ashok Marg',
#        'Sector 105 Block C, Noida Express Way',
#        'Sector 124, Noida Express Way',
#        'Sector 2 Block A, Noida sector 15 Metro', 'Rasoolpur, Sector 63',
#        'Vivek Vihar, Dadri Road', 'Sector 22 Block I',
#        'Kendriya Vihar 2, Sector 82',
#        'Sector 16 Block B, Noida sector 16 Metro', 'Sector 68',
#        'Swarnim Vihar, Sector 82, Dadri Road', 'Sector 31, Ashok Marg',
#        'Sector 105 Block A, Noida Express Way', 'Sector 143B',
#        'Sector 132, Noida Express Way',
#        'Sector 4 Block B, Noida sector 16 Metro',
#        'Udyog Vihar, Sector 82', 'Sector 55', 'Sector 22',
#        'Sector 15 Block D', 'Sector 48 Block C, Dadri Road',
#        'Baraula, Sector 49, Dadri Road', 'Sector 46 Block B',
#        'Phase 2, Sector 81', 'Sector 2 Block C',
#        'Sector 49 Block C, Dadri Road',
#        'Sector 105 Block B, Noida Express Way', 'Sector 66',
#        'Noida sector 16 Metro', 'Sector 72',
#        'Sadarpur, Sector 45, Noida Express Way',
#        'Sector 4 Block A, Noida sector 16 Metro'], dtype=object)

# %%
df_json[df_json.locality=='Noida Extension'].T
# Out:
#                                                                       3     \
# Society                                                Panchsheel Greens 2
# addressLocality                                            Noida Extension
# agentCompanyName                            Panchsheel Buildtech Pvt. Ltd.
# agentMaskedmobilenumber                                    +91-98XXXXXXX82
# agentName                                                        Komal NFE
# bathroom                                                                 2
# bedroom                                                                  2
# builderName                                  Panchsheel Builtech Pvt. Ltd.
# cityName                                                             Noida
# createdDate                                                       20200122
# description              2 Bath,Furnished,18 floor Spread over in 26 ac...
# floorSize                                                        1105 FTK
# floorno                                                                 18
# furnshingstatus                                                  Furnished
# id                                                   domcache_srp_47489765
# latitude                                                         77.407621
# locality                                                   Noida Extension
# longitude                                                          28.5329
# name                           2 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            2
# postedBy                                                           Builder
# price                                                              3480000
# priceInWord                                                       34.8 Lac
# projectName                                            Panchsheel Greens 2
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/2-...
#
#                                                                       5     \
# Society                                                  Saviour Greenarch
# addressLocality                                            Noida Extension
# agentCompanyName                                           Fix Brixs Infra
# agentMaskedmobilenumber                                    +91-98XXXXXXX15
# agentName                                                   Manoj  Chikara
# bathroom                                                                 2
# bedroom                                                                  2
# builderName                                     Saviour Builders Pvt. Ltd.
# cityName                                                             Noida
# createdDate                                                       20200122
# description              2 Bath,Unfurnished,7 floor Saviour Greenarch a...
# floorSize                                                        1180 FTK
# floorno                                                                  7
# furnshingstatus                                                Unfurnished
# id                                                   domcache_srp_45437165
# latitude                                                         77.449731
# locality                                                   Noida Extension
# longitude                                                        28.600152
# name                           2 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            2
# postedBy                                                             Agent
# price                                                              4450000
# priceInWord                                                       44.5 Lac
# projectName                                              Saviour Greenarch
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/2-...
#
#                                                                       12    \
# Society                                                   ATS Happy Trails
# addressLocality                                            Noida Extension
# agentCompanyName                                           Homekraft Infra
# agentMaskedmobilenumber                                    +91-72XXXXXXX17
# agentName                                               Manhar  Srivastava
# bathroom                                                                 3
# bedroom                                                                  3
# builderName                                        ATS Infrastructure Ltd.
# cityName                                                             Noida
# createdDate                                                       20200127
# description              3 Bath,Unfurnished Everyone has a dream of lux...
# floorSize                                                        1385 FTK
# floorno
# furnshingstatus                                                Unfurnished
# id                                                   domcache_srp_46196003
# latitude                                                         77.382996
# locality                                                   Noida Extension
# longitude                                                        28.626491
# name                           3 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            3
# postedBy                                                           Builder
# price                                                              5540000
# priceInWord                                                       55.4 Lac
# projectName                                               ATS Happy Trails
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/3-...
#
#                                                                       13    \
# Society                                                      Amaatra Homes
# addressLocality                                            Noida Extension
# agentCompanyName
# agentMaskedmobilenumber                                    +91-81XXXXXXX84
# agentName                                                    Amaatra Group
# bathroom                                                                 2
# bedroom                                                                  2
# builderName                                                  Amaatra Group
# cityName                                                             Noida
# createdDate                                                       20200113
# description              2 Bath,Unfurnished Amaatra Homes in Greater No...
# floorSize                                                         965 FTK
# floorno
# furnshingstatus                                                Unfurnished
# id                                                   domcache_srp_47257099
# latitude                                                         77.475429
# locality                                                   Noida Extension
# longitude                                                         28.56865
# name                           2 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            2
# postedBy                                                           Builder
# price                                                              3180000
# priceInWord                                                       31.8 Lac
# projectName                                                  Amaatra Homes
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/2-...
#
#                                                                       17    \
# Society                                                     Spring Meadows
# addressLocality                                            Noida Extension
# agentCompanyName                                           Gold Empire Inc
# agentMaskedmobilenumber                                    +91-98XXXXXXX06
# agentName                                                 Praveen  Mallick
# bathroom                                                                 2
# bedroom                                                                  3
# builderName                                    Pigeon Build Home Pvt. Ltd.
# cityName                                                             Noida
# createdDate                                                       20200127
# description              2 Bath,Semi-Furnished,1 floor Enjoy Spring tim...
# floorSize                                                         141 FTK
# floorno                                                                  1
# furnshingstatus                                             Semi-Furnished
# id                                                   domcache_srp_43692599
# latitude                                                             77.44
# locality                                                   Noida Extension
# longitude                                                 28.5897075387749
# name                           3 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            3
# postedBy                                                             Agent
# price                                                              5016000
# priceInWord                                                       50.2 Lac
# projectName                                                 Spring Meadows
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/3-...
#
#                                                                       19    \
# Society                                                  Saviour Greenarch
# addressLocality                                            Noida Extension
# agentCompanyName                      The Trisol Red Infraventures Pvt Ltd
# agentMaskedmobilenumber                                    +91-97XXXXXXX22
# agentName                                                            Pawan
# bathroom                                                                 2
# bedroom                                                                  2
# builderName                                     Saviour Builders Pvt. Ltd.
# cityName                                                             Noida
# createdDate                                                       20191223
# description              2 Bath,Semi-Furnished,10 floor Saviour Greenar...
# floorSize                                                        1180 FTK
# floorno                                                                 10
# furnshingstatus                                             Semi-Furnished
# id                                                   domcache_srp_45469527
# latitude                                                         77.449731
# locality                                                   Noida Extension
# longitude                                                        28.600152
# name                           2 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            2
# postedBy                                                             Agent
# price                                                              4248000
# priceInWord                                                       42.5 Lac
# projectName                                              Saviour Greenarch
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/2-...
#
#                                                                       20    \
# Society                                                     Rhythm CCounty
# addressLocality                                            Noida Extension
# agentCompanyName                                        Propzone Infratech
# agentMaskedmobilenumber                                    +91-81XXXXXXX90
# agentName                                                   Apoorv  Mittal
# bathroom                                                                 2
# bedroom                                                                  3
# builderName                                                   Future World
# cityName                                                             Noida
# createdDate                                                       20190926
# description              2 Bath,Semi-Furnished Rhythm CCounty, one of t...
# floorSize                                                        1395 FTK
# floorno
# furnshingstatus                                             Semi-Furnished
# id                                                   domcache_srp_43887575
# latitude                                                   77.444968582417
# locality                                                   Noida Extension
# longitude                                                 28.5547270791191
# name                           3 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            3
# postedBy                                                             Agent
# price                                                              3900000
# priceInWord                                                         39 Lac
# projectName                                                 Rhythm CCounty
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/3-...
#
#                                                                       21    \
# Society                                                    Mahagun Mywoods
# addressLocality                                            Noida Extension
# agentCompanyName                                     Investors House Infra
# agentMaskedmobilenumber                                    +91-95XXXXXXX00
# agentName                                                      Mukul  Garg
# bathroom                                                                 2
# bedroom                                                                  2
# builderName                                                  Mahagun Group
# cityName                                                             Noida
# createdDate                                                       20190730
# description              2 Bath,Semi-Furnished A home in the woods, yet...
# floorSize                                                        1290 FTK
# floorno
# furnshingstatus                                             Semi-Furnished
# id                                                   domcache_srp_41959031
# latitude                                                         77.425805
# locality                                                   Noida Extension
# longitude                                                        28.620768
# name                           2 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            2
# postedBy                                                             Agent
# price                                                              5030000
# priceInWord                                                       50.3 Lac
# projectName                                                Mahagun Mywoods
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/2-...
#
#                                                                       22    \
# Society                                                    Trident Embassy
# addressLocality                                            Noida Extension
# agentCompanyName                                   Globic Homes Consulting
# agentMaskedmobilenumber                                    +91-88XXXXXXX77
# agentName                                                    Manoj  Sharma
# bathroom                                                                 5
# bedroom                                                                  4
# builderName                                   Trident Infrahomes Pvt. Ltd.
# cityName                                                             Noida
# createdDate                                                       20191022
# description              5 Bath,Semi-Furnished,North - East facing The ...
# floorSize                                                        2285 FTK
# floorno
# furnshingstatus                                             Semi-Furnished
# id                                                   domcache_srp_34139401
# latitude                                                         77.444314
# locality                                                   Noida Extension
# longitude                                                        28.570765
# name                           4 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            4
# postedBy                                                             Agent
# price                                                              8157450
# priceInWord                                                       81.6 Lac
# projectName                                                Trident Embassy
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/4-...
#
#                                                                       31    \
# Society                                                     Himalaya Pride
# addressLocality                                            Noida Extension
# agentCompanyName                               Kartik Infra Town Pvt. Ltd.
# agentMaskedmobilenumber                                    +91-98XXXXXXX35
# agentName                                                   Sachin Sangwan
# bathroom                                                                 2
# bedroom                                                                  3
# builderName                                                 Himalaya Group
# cityName                                                             Noida
# createdDate                                                       20191127
# description              2 Bath,Semi-Furnished Himalaya Pride is the ne...
# floorSize                                                        1188 FTK
# floorno
# furnshingstatus                                             Semi-Furnished
# id                                                   domcache_srp_37040537
# latitude                                                  77.4516993023192
# locality                                                   Noida Extension
# longitude                                                 28.5989961135044
# name                           3 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            3
# postedBy                                                           Builder
# price                                                              4030000
# priceInWord                                                       40.3 Lac
# projectName                                                 Himalaya Pride
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/3-...
#
#                          ...  \
# Society                  ...
# addressLocality          ...
# agentCompanyName         ...
# agentMaskedmobilenumber  ...
# agentName                ...
# bathroom                 ...
# bedroom                  ...
# builderName              ...
# cityName                 ...
# createdDate              ...
# description              ...
# floorSize                ...
# floorno                  ...
# furnshingstatus          ...
# id                       ...
# latitude                 ...
# locality                 ...
# longitude                ...
# name                     ...
# numberOfRooms            ...
# postedBy                 ...
# price                    ...
# priceInWord              ...
# projectName              ...
# propertyType             ...
# url                      ...
#
#                                                                       2467  \
# Society
# addressLocality                                            Noida Extension
# agentCompanyName
# agentMaskedmobilenumber                                    +91-99XXXXXXX82
# agentName                                                          Rajnish
# bathroom                                                                 1
# bedroom                                                                  1
# builderName
# cityName                                                             Noida
# createdDate                                                       20191021
# description              1 Bath,Semi-Furnished,3 floor   Multistorey Ap...
# floorSize                                                         460 FTK
# floorno                                                                  3
# furnshingstatus                                             Semi-Furnished
# id                                                   domcache_srp_45566021
# latitude
# locality                                                   Noida Extension
# longitude
# name                           1 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            1
# postedBy                                                             Owner
# price                                                              1900000
# priceInWord                                                         19 Lac
# projectName
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/1-...
#
#                                                                       2498  \
# Society
# addressLocality                                            Noida Extension
# agentCompanyName
# agentMaskedmobilenumber                                    +91-98XXXXXXX75
# agentName                                                     Ajesh Chawla
# bathroom                                                                 2
# bedroom                                                                  2
# builderName
# cityName                                                             Noida
# createdDate                                                       20191123
# description              2 Bath,Unfurnished,13 floor Multistorey apartm...
# floorSize                                                         890 FTK
# floorno                                                                 13
# furnshingstatus                                                Unfurnished
# id                                                   domcache_srp_46253077
# latitude                                                 77.40760040283203
# locality                                                   Noida Extension
# longitude                                               28.532350540161133
# name                           2 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            2
# postedBy                                                             Owner
# price                                                              3000000
# priceInWord                                                         30 Lac
# projectName
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/2-...
#
#                                                                       2516  \
# Society
# addressLocality                                            Noida Extension
# agentCompanyName
# agentMaskedmobilenumber                                    +91-98XXXXXXX27
# agentName                                                      shikha jain
# bathroom                                                                 2
# bedroom                                                                  3
# builderName
# cityName                                                             Noida
# createdDate                                                       20191016
# description              2 Bath,Semi-Furnished,12 floor   Multistorey A...
# floorSize                                                        1530 FTK
# floorno                                                                 12
# furnshingstatus                                             Semi-Furnished
# id                                                   domcache_srp_45453223
# latitude
# locality                                                   Noida Extension
# longitude
# name                           3 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            3
# postedBy                                                             Owner
# price                                                              6500000
# priceInWord                                                         65 Lac
# projectName
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/3-...
#
#                                                                       2541  \
# Society
# addressLocality                                            Noida Extension
# agentCompanyName
# agentMaskedmobilenumber                                    +91-83XXXXXXX02
# agentName                                                             Deep
# bathroom                                                                 2
# bedroom                                                                  2
# builderName
# cityName                                                             Noida
# createdDate                                                       20191024
# description              2 Bath,Semi-Furnished,14 floor  This Multistor...
# floorSize                                                         909 FTK
# floorno                                                                 14
# furnshingstatus                                             Semi-Furnished
# id                                                   domcache_srp_45632191
# latitude
# locality                                                   Noida Extension
# longitude
# name                           2 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            2
# postedBy                                                             Owner
# price                                                              3500000
# priceInWord                                                         35 Lac
# projectName
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/2-...
#
#                                                                       2544  \
# Society
# addressLocality                                            Noida Extension
# agentCompanyName
# agentMaskedmobilenumber                                    +91-94XXXXXXX91
# agentName                                                       rb rathore
# bathroom                                                                 2
# bedroom                                                                  2
# builderName
# cityName                                                             Noida
# createdDate                                                       20191016
# description              2 Bath,Unfurnished,6 floor  It's a 6th floor M...
# floorSize                                                        1185 FTK
# floorno                                                                  6
# furnshingstatus                                                Unfurnished
# id                                                   domcache_srp_45462057
# latitude
# locality                                                   Noida Extension
# longitude
# name                           2 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            2
# postedBy                                                             Owner
# price                                                              5000000
# priceInWord                                                         50 Lac
# projectName
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/2-...
#
#                                                                       2553  \
# Society
# addressLocality                                            Noida Extension
# agentCompanyName
# agentMaskedmobilenumber                                    +91-96XXXXXXX83
# agentName                                                          PRADEEP
# bathroom                                                                 3
# bedroom                                                                  3
# builderName
# cityName                                                             Noida
# createdDate                                                       20200123
# description              3 Bath,Semi-Furnished,23 floor,East facing Mul...
# floorSize                                                        1320 FTK
# floorno                                                                 23
# furnshingstatus                                             Semi-Furnished
# id                                                   domcache_srp_44155079
# latitude
# locality                                                   Noida Extension
# longitude
# name                           3 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            3
# postedBy                                                             Owner
# price                                                              5700000
# priceInWord                                                         57 Lac
# projectName
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/3-...
#
#                                                                       2558  \
# Society
# addressLocality                                            Noida Extension
# agentCompanyName
# agentMaskedmobilenumber                                    +91-95XXXXXXX35
# agentName                                                           Deepak
# bathroom                                                                 2
# bedroom                                                                  2
# builderName
# cityName                                                             Noida
# createdDate                                                       20200111
# description              2 Bath,Unfurnished,9 floor 2 BHK, Multistorey ...
# floorSize                                                         870 FTK
# floorno                                                                  9
# furnshingstatus                                                Unfurnished
# id                                                   domcache_srp_47279085
# latitude
# locality                                                   Noida Extension
# longitude
# name                           2 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            2
# postedBy                                                             Owner
# price                                                              2800000
# priceInWord                                                         28 Lac
# projectName
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/2-...
#
#                                                                       2574  \
# Society
# addressLocality                                            Noida Extension
# agentCompanyName
# agentMaskedmobilenumber                                    +91-88XXXXXXX50
# agentName                                                       Vipul Jain
# bathroom                                                                 3
# bedroom                                                                  3
# builderName
# cityName                                                             Noida
# createdDate                                                       20200111
# description              3 Bath,Unfurnished,4 floor 3 BHK, Multistorey ...
# floorSize                                                        1230 FTK
# floorno                                                                  4
# furnshingstatus                                                Unfurnished
# id                                                   domcache_srp_47269687
# latitude
# locality                                                   Noida Extension
# longitude
# name                           3 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            3
# postedBy                                                             Owner
# price                                                              4000000
# priceInWord                                                         40 Lac
# projectName
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/3-...
#
#                                                                       2582  \
# Society
# addressLocality                                            Noida Extension
# agentCompanyName
# agentMaskedmobilenumber                                    +91-70XXXXXXX50
# agentName                                                             anuj
# bathroom                                                                 1
# bedroom                                                                  1
# builderName
# cityName                                                             Noida
# createdDate                                                       20191221
# description              1 Bath,Unfurnished,12 floor 1 BHK, Multistorey...
# floorSize                                                         580 FTK
# floorno                                                                 12
# furnshingstatus                                                Unfurnished
# id                                                   domcache_srp_46851477
# latitude
# locality                                                   Noida Extension
# longitude
# name                           1 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            1
# postedBy                                                             Owner
# price                                                              2500000
# priceInWord                                                         25 Lac
# projectName
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/1-...
#
#                                                                       2593
# Society
# addressLocality                                            Noida Extension
# agentCompanyName
# agentMaskedmobilenumber                                    +91-98XXXXXXX11
# agentName                                                            Fazal
# bathroom                                                                 2
# bedroom                                                                  3
# builderName
# cityName                                                             Noida
# createdDate                                                       20200108
# description              2 Bath,Semi-Furnished,18 floor 3 BHK, Multisto...
# floorSize                                                        1495 FTK
# floorno                                                                 18
# furnshingstatus                                             Semi-Furnished
# id                                                   domcache_srp_47206657
# latitude
# locality                                                   Noida Extension
# longitude
# name                           3 BHK Apartment for Sale in Noida Extension
# numberOfRooms                                                            3
# postedBy                                                             Owner
# price                                                              6500000
# priceInWord                                                         65 Lac
# projectName
# propertyType                                                     Apartment
# url                      https://www.magicbricks.com/propertyDetails/3-...
#
# [26 rows x 331 columns]

# %%
df_json['createdDate']=pd.to_datetime(df_json['createdDate'])

# %%
df_json['createdDate'].min()
# Out:
# Timestamp('2019-07-30 00:00:00')
